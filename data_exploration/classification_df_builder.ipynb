# %% [markdown]
# # Merging Datasets to one Dataframe (.csv)

# %% [markdown]
# quellen https://hackernoon.com/14-open-datasets-for-text-classification-in-machine-learning-xd1u3wit
#
# 1. emails https://archive.ics.uci.edu/ml/machine-learning-databases/spambase/?ref=hackernoon.com
# 2. blogs https://u.cs.biu.ac.il/~koppel/BlogCorpus.htm?ref=hackernoon.com, https://www.kaggle.com/datasets/saurabhbagchi/sample-blog-corpus
# 3. news https://www.kaggle.com/datasets/benjaminawd/new-york-times-articles-comments-2020, https://www.kaggle.com/datasets/sunnysai12345/news-summary?select=news_summary.csv
# 4. products_reviews https://www.kaggle.com/datasets/kritanjalijain/amazon-reviews?select=test.csv
# 5. poems https://www.kaggle.com/datasets/michaelarman/poemsdataset
# 6. paper https://www.kaggle.com/datasets/benhamner/nips-papers?select=papers.csv
# 7. recipes https://www.kaggle.com/datasets/irkaal/foodcom-recipes-and-reviews

# %%
import pandas as pd

# %% [markdown]
# ## emails

# %%
# Read in the data from emails.csv
df = pd.read_csv('./data/emails/emails.csv')

# %%
df.head()
# Out:
#                        file                                            message
# 0     allen-p/_sent_mail/1.  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1    allen-p/_sent_mail/10.  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2   allen-p/_sent_mail/100.  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3  allen-p/_sent_mail/1000.  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4  allen-p/_sent_mail/1001.  Message-ID: <30922949.1075863688243.JavaMail.e...

# %%
df['file'] = 1
df['kategorie_bezeichnung'] = 'email'
df.rename(columns={'file':'kategorie_id','message':'inhalt'}, inplace=True)

# %%
df.head()
# Out:
#    kategorie_id                                             inhalt  \
# 0             1  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1             1  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2             1  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3             1  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4             1  Message-ID: <30922949.1075863688243.JavaMail.e...
#
#   kategorie_bezeichnung
# 0                 email
# 1                 email
# 2                 email
# 3                 email
# 4                 email

# %%
# view content of first row
print(df.message.iloc[1])
# Out:
# Message-ID: <15464986.1075855378456.JavaMail.evans@thyme>
# Date: Fri, 4 May 2001 13:51:00 -0700 (PDT)
# From: phillip.allen@enron.com
# To: john.lavorato@enron.com
# Subject: Re:
# Mime-Version: 1.0
# Content-Type: text/plain; charset=us-ascii
# Content-Transfer-Encoding: 7bit
# X-From: Phillip K Allen
# X-To: John J Lavorato <John J Lavorato/ENRON@enronXgate@ENRON>
# X-cc:
# X-bcc:
# X-Folder: \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Sent Mail
# X-Origin: Allen-P
# X-FileName: pallen (Non-Privileged).pst
#
# Traveling to have a business meeting takes the fun out of the trip.  Especially if you have to prepare a presentation.  I would suggest holding the business plan meetings here then take a trip without any formal business meetings.  I would even try and get some honest opinions on whether a trip is even desired or necessary.
#
# As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.  Too often the presenter speaks and the others are quiet just waiting for their turn.   The meetings might be better if held in a round table discussion format.
#
# My suggestion for where to go is Austin.  Play golf and rent a ski boat and jet ski's.  Flying somewhere takes too much time.

# %% [markdown]
# ## blogs

# %%
df_blog = pd.read_csv('./data/blogs/blogtext.csv')

# %%
df_blog['kategorie_id'] = 2
df_blog['kategorie_bezeichnung'] = 'blog'
df_blog.rename(columns={'text':'inhalt'}, inplace=True)

# %%
df_blog.drop(['id','gender','age','topic','sign','date'], axis=1, inplace=True)

# %%
df_blog.drop(['word_count'], inplace=True, axis=1)

# %%
df_blog.head()
# Out:
#                                               inhalt  kategorie_id  \
# 0             Info has been found (+/- 100 pages,...             2
# 1             These are the team members:   Drewe...             2
# 2             In het kader van kernfusie op aarde...             2
# 3                   testing!!!  testing!!!                       2
# 4               Thanks to Yahoo!'s Toolbar I can ...             2
#
#   kategorie_bezeichnung
# 0                  blog
# 1                  blog
# 2                  blog
# 3                  blog
# 4                  blog

# %%
print(df_blog.inhalt.iloc[4])
# Out:
#              Thanks to Yahoo!'s Toolbar I can now 'capture' the URLs of popups...which means now I can show you some cool links to Korean Pop (K-Pop) audio and video without the need to relate instructions like: 'go to the site, click on the pop-audio button then choose...'.  So, without further ado here is the link to 24-hour K-Pop  urlLink audio  and the  urlLink video  streaming.  Enjoy.

# %%
# df_blog["word_count"] = df_blog.text.apply(lambda x: len(x.split()))

# %%
df_blog.describe()
# Out:
#        kategorie_id
# count      681284.0
# mean            2.0
# std             0.0
# min             2.0
# 25%             2.0
# 50%             2.0
# 75%             2.0
# max             2.0

# %%
# df_blog.word_count.plot(kind='box')

# %% [markdown]
# ## news

# %%
df_news = pd.read_csv('./data/news/news_summary.csv', encoding='latin-1')

# %%
df_news["text_wordcount"] = df_news.text.apply(lambda x: len(x.split()))
df_news["ctext_wordcount"] = df_news.ctext.apply(lambda x: len(str(x).split()))

# %%
df_news.head()
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
#                                                 text  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                                ctext  text_wordcount  \
# 0  The Daman and Diu administration on Wednesday ...              60
# 1  From her special numbers to TV?appearances, Bo...              60
# 2  The Indira Gandhi Institute of Medical Science...              60
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...              60
# 4  Hotels in Mumbai and other Indian cities are t...              60
#
#    ctext_wordcount
# 0              364
# 1              396
# 2              335
# 3              404
# 4              526

# %%
df_news.describe()
# Out:
#        text_wordcount  ctext_wordcount
# count     4514.000000      4514.000000
# mean        58.287328       334.125831
# std          2.320266       357.069264
# min         44.000000         1.000000
# 25%         57.000000       176.000000
# 50%         59.000000       277.000000
# 75%         60.000000       406.000000
# max         62.000000     12202.000000

# %%
df_news['kategorie_id'] = 3
df_news['kategorie_bezeichnung'] = 'news'
df_news.drop(['author','date','read_more','text_wordcount','text_wordcount','ctext_wordcount'], axis=1, inplace=True)
df_news.rename(columns={'text':'inhalt','ctext':'inhalt_kurz'}, inplace=True)

# %%
df_news.rename(columns={'headlines':'titel'}, inplace=True)

# %%
df_news.head()
# Out:
#                                                titel  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                               inhalt  \
# 0  The Administration of Union Territory Daman an...
# 1  Malaika Arora slammed an Instagram user who tr...
# 2  The Indira Gandhi Institute of Medical Science...
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...
# 4  Hotels in Maharashtra will train their staff t...
#
#                                          inhalt_kurz  kategorie_id  \
# 0  The Daman and Diu administration on Wednesday ...             3
# 1  From her special numbers to TV?appearances, Bo...             3
# 2  The Indira Gandhi Institute of Medical Science...             3
# 3  Lashkar-e-Taiba's Kashmir commander Abu Dujana...             3
# 4  Hotels in Mumbai and other Indian cities are t...             3
#
#   kategorie_bezeichnung
# 0                  news
# 1                  news
# 2                  news
# 3                  news
# 4                  news

# %% [markdown]
# ## reviews

# %%
df_reviews = pd.read_csv('./data/reviews/test.csv')

# %%
df_reviews.head()
# Out:
#    cat                                            betreff  \
# 0    2                                           Great CD
# 1    2  One of the best game music soundtracks - for a...
# 2    1                   Batteries died within a year ...
# 3    2              works fine, but Maha Energy is better
# 4    2                       Great for the non-audiophile
#
#                                              content
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
# 2  I bought this charger in Jul 2003 and it worke...
# 3  Check out Maha Energy's website. Their Powerex...
# 4  Reviewed quite a bit of the combo players and ...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   cat      400000 non-null  int64
#  1   betreff  399990 non-null  object
#  2   content  400000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 9.2+ MB

# %%
df_reviews.describe()
# Out:
#                  cat
# count  400000.000000
# mean        1.500000
# std         0.500001
# min         1.000000
# 25%         1.000000
# 50%         1.500000
# 75%         2.000000
# max         2.000000

# %%
df_reviews['kategorie_id'] = 4
df_reviews['kategorie_bezeichnung'] = 'review'
df_reviews.rename(columns={'betreff':'titel','content':'inhalt'}, inplace=True)

# %%
df_reviews.drop(['cat'], axis=1, inplace=True)

# %%
df_reviews.head()
# Out:
#                                                titel  \
# 0                                           Great CD
# 1  One of the best game music soundtracks - for a...
# 2                   Batteries died within a year ...
# 3              works fine, but Maha Energy is better
# 4                       Great for the non-audiophile
#
#                                               inhalt  kategorie_id  \
# 0  My lovely Pat has one of the GREAT voices of h...             4
# 1  Despite the fact that I have only played a sma...             4
# 2  I bought this charger in Jul 2003 and it worke...             4
# 3  Check out Maha Energy's website. Their Powerex...             4
# 4  Reviewed quite a bit of the combo players and ...             4
#
#   kategorie_bezeichnung
# 0                review
# 1                review
# 2                review
# 3                review
# 4                review

# %% [markdown]
# ## poems

# %%
# read in data from poems/forms folder and save content to df
import os
import csv

def save_txt_to_csv(folder_path, csv_file_path):
    with open(csv_file_path, 'w', newline='') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow(['Folder', 'Filename', 'Content'])  # Write header row
        
        for root, dirs, files in os.walk(folder_path):
            for file_name in files:
                if file_name.endswith('.txt'):
                    folder_name = os.path.basename(root)
                    file_path = os.path.join(root, file_name)
                    with open(file_path, 'r') as txt_file:
                        content = txt_file.read()
                    writer.writerow([folder_name, file_name, content])

# Example usage
folder_path = 'F:\Github_local\BA_data\Projektrealisierung_Gruppe_1\data_exploration\data\poems'  # Replace with the actual path to the "poems" folder
csv_file_path = 'F:\Github_local\BA_data\Projektrealisierung_Gruppe_1\data_exploration\data\poems\output.csv'  # Replace with your desired CSV file path

save_txt_to_csv(folder_path, csv_file_path)

# %%
df_poems = pd.read_csv('./data/poems/output.csv')

# %%
df_poems.describe()
# Out:
#             Folder                                           Filename  \
# count         6322                                               6322
# unique         135                                               6322
# top     villanelle  AbcPoems2AbcHkAndChinaV2Cauchy3Poembycheungshu...
# freq           100                                                  1
#
#                                                   Content
# count                                                6321
# unique                                               6117
# top     Through the window I see that\nYou are walking...
# freq                                                    3

# %%
df_poems
# Out:
#           Folder                                           Filename  \
# 0            abc  AbcPoems2AbcHkAndChinaV2Cauchy3Poembycheungshu...
# 1            abc  AbcPoems887LiveWithLoveAnAbcPoemPoembyMelvinaG...
# 2            abc  AbcPoemsAAbcAnglesOnAngelsPoemByCauchy3Poembyc...
# 3            abc  AbcPoemsAAbcBrazilDancePoemByCauchy3Poembycheu...
# 4            abc            AbcPoemsAbc123PoembyGabriellaFranco.txt
# ...          ...                                                ...
# 6317  villanelle  VillanellePoemsWhippomorphaVillanellePoembyDia...
# 6318  villanelle  VillanellePoemsWillAndElleAVillanellePoembyDia...
# 6319  villanelle  VillanellePoemsWishWishTheDarknessAllAwayVilla...
# 6320  villanelle  VillanellePoemsYouAreFromMeSoFarAwayVillanelle...
# 6321  villanelle  VillanellePoemsYouArePresentInEachAndEveryHear...
#
#                                                 Content
# 0     2 ABC of H.k. and China revised vision.\nBarre...
# 1     Apparently life without love, is no life at al...
# 2     A abc angles on angels flaws (poem)\nMix with ...
# 3     A abc Brazil dance (poem)\nJack of crack in po...
# 4     ABC... I can't go on\n123... what's the next o...
# ...                                                 ...
# 6317  “Greatest Auntie strayed at Oncewas Bay\nwhile...
# 6318  'I don't believe in free will', ventured he,\n...
# 6319  So comes the end of another day,\nDig the grav...
# 6320  While LM Radio does my favourite music play,\n...
# 6321  It's as if it's you and our grandchildren I wa...
#
# [6322 rows x 3 columns]

# %%
df_poems['kategorie_id'] = 5
df_poems['kategorie_bezeichnung'] = 'poem'
df_poems.rename(columns={'Content':'inhalt'}, inplace=True)
df_poems.drop(['Folder','Filename'], axis=1, inplace=True)

# %%
df_poems.head()
# Out:
#                                               inhalt  kategorie_id  \
# 0  2 ABC of H.k. and China revised vision.\nBarre...             5
# 1  Apparently life without love, is no life at al...             5
# 2  A abc angles on angels flaws (poem)\nMix with ...             5
# 3  A abc Brazil dance (poem)\nJack of crack in po...             5
# 4  ABC... I can't go on\n123... what's the next o...             5
#
#   kategorie_bezeichnung
# 0                  poem
# 1                  poem
# 2                  poem
# 3                  poem
# 4                  poem

# %% [markdown]
# ## paper

# %%
df_papers = pd.read_csv('./data/paper/papers.csv')

# %%
df_papers.head()
# Out:
#      id  year                                              title event_type  \
# 0     1  1987  Self-Organization of Associative Database and ...        NaN
# 1    10  1987  A Mean Field Theory of Layer IV of Visual Cort...        NaN
# 2   100  1988  Storing Covariance by the Associative Long-Ter...        NaN
# 3  1000  1994  Bayesian Query Construction for Neural Network...        NaN
# 4  1001  1994  Neural Network Ensembles, Cross Validation, an...        NaN
#
#                                             pdf_name          abstract  \
# 0  1-self-organization-of-associative-database-an...  Abstract Missing
# 1  10-a-mean-field-theory-of-layer-iv-of-visual-c...  Abstract Missing
# 2  100-storing-covariance-by-the-associative-long...  Abstract Missing
# 3  1000-bayesian-query-construction-for-neural-ne...  Abstract Missing
# 4  1001-neural-network-ensembles-cross-validation...  Abstract Missing
#
#                                           paper_text
# 0  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...
# 1  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...
# 2  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...
# 3  Bayesian Query Construction for Neural\nNetwor...
# 4  Neural Network Ensembles, Cross\nValidation, a...

# %%
df_papers["word_count"] = df_papers.paper_text.apply(lambda x: len(x.split()))

# %%
df_papers.describe()
# Out:
#                 id         year    word_count
# count  7241.000000  7241.000000   7241.000000
# mean   3655.912167  2006.439718   4849.317912
# std    2098.435219     8.759919   1411.949448
# min       1.000000  1987.000000      0.000000
# 25%    1849.000000  2000.000000   3639.000000
# 50%    3659.000000  2009.000000   5102.000000
# 75%    5473.000000  2014.000000   5898.000000
# max    7284.000000  2017.000000  22249.000000

# %%
df_papers['kategorie_id'] = 6
df_papers['kategorie_bezeichnung'] = 'paper'
df_papers.rename(columns={'paper_text':'inhalt','abstract':'inhalt_kurz','title':'titel'}, inplace=True)
df_papers.drop(['id','year','event_type','pdf_name','word_count'], axis=1, inplace=True)

# %%
df_papers.head()
# Out:
#                                                titel       inhalt_kurz  \
# 0  Self-Organization of Associative Database and ...  Abstract Missing
# 1  A Mean Field Theory of Layer IV of Visual Cort...  Abstract Missing
# 2  Storing Covariance by the Associative Long-Ter...  Abstract Missing
# 3  Bayesian Query Construction for Neural Network...  Abstract Missing
# 4  Neural Network Ensembles, Cross Validation, an...  Abstract Missing
#
#                                               inhalt  kategorie_id  \
# 0  767\n\nSELF-ORGANIZATION OF ASSOCIATIVE DATABA...             6
# 1  683\n\nA MEAN FIELD THEORY OF LAYER IV OF VISU...             6
# 2  394\n\nSTORING COVARIANCE BY THE ASSOCIATIVE\n...             6
# 3  Bayesian Query Construction for Neural\nNetwor...             6
# 4  Neural Network Ensembles, Cross\nValidation, a...             6
#
#   kategorie_bezeichnung
# 0                 paper
# 1                 paper
# 2                 paper
# 3                 paper
# 4                 paper

# %% [markdown]
# ## recipes

# %%
df_recipes = pd.read_csv('./data/recipes/recipes.csv')

# %%
df_recipes.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                               Images  ... SaturatedFatContent  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  ...                 1.3
# 1  c("https://img.sndimg.com/food/image/upload/w_...  ...                16.6
# 2  c("https://img.sndimg.com/food/image/upload/w_...  ...                 0.0
# 3  c("https://img.sndimg.com/food/image/upload/w_...  ...                 3.8
# 4  "https://img.sndimg.com/food/image/upload/w_55...  ...                 0.1
#
#   CholesterolContent SodiumContent CarbohydrateContent  FiberContent  \
# 0                8.0          29.8                37.1           3.6
# 1              372.8         368.4                84.4           9.0
# 2                0.0           1.8                81.5           0.4
# 3                0.0        1558.6                64.2          17.3
# 4                0.0         959.3                25.1           4.8
#
#    SugarContent  ProteinContent  RecipeServings  RecipeYield  \
# 0          30.2             3.2             4.0          NaN
# 1          20.4            63.4             6.0          NaN
# 2          77.2             0.3             4.0          NaN
# 3          32.1            29.3             2.0     4 kebabs
# 4          17.7             4.3             4.0          NaN
#
#                                   RecipeInstructions
# 0  c("Toss 2 cups berries with sugar.", "Let stan...
# 1  c("Soak saffron in warm milk for 5 minutes and...
# 2  c("Into a 1 quart Jar with tight fitting lid, ...
# 3  c("Drain the tofu, carefully squeezing out exc...
# 4  c("Mix everything together and bring to a boil...
#
# [5 rows x 28 columns]

# %%
# show contenct of description column from first row
print(df_recipes["RecipeInstructions"].iloc[2])
# Out:
# c("Into a 1 quart Jar with tight fitting lid, put sugar and lemon peel, or zest;  add 1 1/2 cups very hot water (not from tap!). With lid fitted firmly, shake jar until sugar is dissolved.", "Add lemon juice. Refrigerate until chilled.", "To Serve: Into each 12-ounce glass, over ice cubes, pour 1/4 cup of the lemon syrup.", "Then add chilled club soda or, if you prefer, water.", "Stir to mix well.")

# %%
df_recipes["kategorie_id"] = 7
df_recipes["kategorie_bezeichnung"] = "recipe"
df_recipes.drop(['RecipeId', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime',
       'TotalTime', 'DatePublished', 'Images', 'RecipeCategory',
       'Keywords', 'RecipeIngredientQuantities', 'RecipeIngredientParts',
       'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
       'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
       'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
       'RecipeServings', 'RecipeYield'], axis=1, inplace=True)

# %%
df_recipes.head()
# Out:
#                                titel  \
# 0  Low-Fat Berry Blue Frozen Dessert
# 1                            Biryani
# 2                      Best Lemonade
# 3     Carina's Tofu-Vegetable Kebabs
# 4                       Cabbage Soup
#
#                                          inhalt_kurz  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# 2  This is from one of my  first Good House Keepi...
# 3  This dish is best prepared a day in advance to...
# 4  Make and share this Cabbage Soup recipe from F...
#
#                                   RecipeInstructions  kategorie_id  \
# 0  c("Toss 2 cups berries with sugar.", "Let stan...             7
# 1  c("Soak saffron in warm milk for 5 minutes and...             7
# 2  c("Into a 1 quart Jar with tight fitting lid, ...             7
# 3  c("Drain the tofu, carefully squeezing out exc...             7
# 4  c("Mix everything together and bring to a boil...             7
#
#   kategorie_bezeichnung
# 0                recipe
# 1                recipe
# 2                recipe
# 3                recipe
# 4                recipe

# %%
df_recipes.rename(columns={'Name':'titel','RecipeInstructions':'inhalt','Description':'inhalt_kurz'}, inplace=True)

# %% [markdown]
# ## merge data

# %%
# merge datasets
complete_df = pd.concat([df, df_blog, df_news, df_reviews, df_poems, df_papers, df_recipes], ignore_index=True)

# %%
# select subset of data where kategorie_id is 1
complete_df[complete_df['kategorie_id'] == 1]
# Out:
#         kategorie_id                                             inhalt  \
# 0                  1  Message-ID: <18782981.1075855378110.JavaMail.e...
# 1                  1  Message-ID: <15464986.1075855378456.JavaMail.e...
# 2                  1  Message-ID: <24216240.1075855687451.JavaMail.e...
# 3                  1  Message-ID: <13505866.1075863688222.JavaMail.e...
# 4                  1  Message-ID: <30922949.1075863688243.JavaMail.e...
# ...              ...                                                ...
# 517396             1  Message-ID: <26807948.1075842029936.JavaMail.e...
# 517397             1  Message-ID: <25835861.1075842029959.JavaMail.e...
# 517398             1  Message-ID: <28979867.1075842029988.JavaMail.e...
# 517399             1  Message-ID: <22052556.1075842030013.JavaMail.e...
# 517400             1  Message-ID: <28618979.1075842030037.JavaMail.e...
#
#        kategorie_bezeichnung titel inhalt_kurz
# 0                      email   NaN         NaN
# 1                      email   NaN         NaN
# 2                      email   NaN         NaN
# 3                      email   NaN         NaN
# 4                      email   NaN         NaN
# ...                      ...   ...         ...
# 517396                 email   NaN         NaN
# 517397                 email   NaN         NaN
# 517398                 email   NaN         NaN
# 517399                 email   NaN         NaN
# 517400                 email   NaN         NaN
#
# [517401 rows x 5 columns]

# %%
complete_df = complete_df[['kategorie_id','kategorie_bezeichnung','titel','inhalt_kurz','inhalt']]

# %%
complete_df.to_csv('./data/complete_data.csv', index=False)

# %%
complete_df.kategorie_id.value_counts()
# Out:
# 2    681284
# 7    522517
# 1    517401
# 4    400000
# 6      7241
# 5      6322
# 3      4514
# Name: kategorie_id, dtype: int64

# %%
complete_df.kategorie_id.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# create subset of data with only 1000 rows per category
df_subset = complete_df.groupby('kategorie_id').head(4500)

# %%
df_subset.kategorie_id.value_counts()
# Out:
# 1    4500
# 2    4500
# 3    4500
# 4    4500
# 5    4500
# 6    4500
# 7    4500
# Name: kategorie_id, dtype: int64

# %%
df_subset.kategorie_id.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_subset.to_csv('./data/complete_data_subset.csv', index=False)
