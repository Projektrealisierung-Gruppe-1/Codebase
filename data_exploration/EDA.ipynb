# %%
# data exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
from autoviz.AutoViz_Class import AutoViz_Class

# %%
df = pd.read_csv('./data/nyt-articles-2020.csv')

# %%
df.head()
# Out:
#     newsdesk             section subsection             material  \
# 0  Editorial             Opinion        NaN            Editorial
# 1      Games  Crosswords & Games        NaN                 News
# 2    Science             Science        NaN                 News
# 3    Science             Science        NaN  Interactive Feature
# 4    Science             Science        NaN                 News
#
#                                             headline  \
# 0                        Protect Veterans From Fraud
# 1                             ‘It’s Green and Slimy’
# 2  Meteor Showers in 2020 That Will Light Up Nigh...
# 3           Sync your calendar with the solar system
# 4  Rocket Launches, Trips to Mars and More 2020 S...
#
#                                             abstract  \
# 0  Congress could do much more to protect America...
# 1  Christina Iverson and Jeff Chen ring in the Ne...
# 2  All year long, Earth passes through streams of...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16787 entries, 0 to 16786
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   newsdesk    16787 non-null  object
#  1   section     16787 non-null  object
#  2   subsection  5693 non-null   object
#  3   material    16787 non-null  object
#  4   headline    16787 non-null  object
#  5   abstract    16784 non-null  object
#  6   keywords    16786 non-null  object
#  7   word_count  16787 non-null  int64
#  8   pub_date    16787 non-null  object
#  9   n_comments  16787 non-null  int64
#  10  uniqueID    16787 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#          word_count    n_comments
# count  16787.000000  16787.000000
# mean    1301.097516    297.043009
# std      944.937307    513.406953
# min        0.000000      1.000000
# 25%      874.000000     21.000000
# 50%     1183.000000     87.000000
# 75%     1502.000000    323.000000
# max    15619.000000   8987.000000

# %%
df.newsdesk.value_counts()
# Out:
# OpEd          1996
# Foreign       1073
# Culture       1050
# Business       981
# Washington     843
#               ...
# At Home          2
# Movies           2
# Photo            1
# Graphics         1
# Live             1
# Name: newsdesk, Length: 63, dtype: int64

# %%
df

# %%
df.newsdesk.value_counts().plot(kind='barh', figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# autoviz for quick data exploration
AV = AutoViz_Class()
dft = AV.AutoViz(filename="./data/nyt-articles-2020.csv", chart_format="svg")
# Out:
# Shape of your Data Set loaded: (16787, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     11 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 3
# Could not draw wordcloud plot for headline
# Could not draw wordcloud plot for abstract
# Could not draw wordcloud plot for keywords
# Could not draw wordcloud plot for uniqueID
# Time to run AutoViz = 6 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
